# %%
import pandas as pd
import requests
import os
from datetime import date
import geopandas as gpd

# %% [markdown]
# ##### *fetch*

# %%
week = gpd.read_file(r'D:\custom_analysis\data\week_route_history.geojson')
week["weekend"] = False
weekend = gpd.read_file(r'D:\custom_analysis\data\weekend_route_history.geojson')
weekend["weekend"] = True

df_all = pd.concat([week,weekend])

# %%
url = "https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json"
response = requests.get(url)

df = pd.DataFrame(response.json())
valid = df.query(f'infoDate >= "{date.today().strftime('%Y-%m-%d')}"')
valid["sna"] = valid["sna"].str.replace("YouBike2.0_","")

# to_return = valid[["sna", 'latitude', 'longitude','available_rent_bikes','available_return_bikes','total']]
# Out:
# C:\Users\tonyf\AppData\Local\Temp\ipykernel_1952\310593410.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid["sna"] = valid["sna"].str.replace("YouBike2.0_","")

# %%
valid.columns
# Out:
# Index(['sno', 'sna', 'sarea', 'mday', 'ar', 'sareaen', 'snaen', 'aren', 'act',
#        'srcUpdateTime', 'updateTime', 'infoTime', 'infoDate', 'total',
#        'available_rent_bikes', 'latitude', 'longitude',
#        'available_return_bikes'],
#       dtype='object')

# %%
valid
# Out:
#             sno          sna   sarea                 mday             ar  \
# 0     500101001      捷運科技大樓站     大安區  2024-11-08 08:00:17    復興南路二段235號前
# 1     500101002  復興南路二段273號前     大安區  2024-11-08 07:57:15   復興南路二段273號西側
# 2     500101003    國北教大實小東側門     大安區  2024-11-08 07:59:16    和平東路二段96巷7號
# 3     500101004       和平公園東側     大安區  2024-11-08 07:59:16  和平東路二段118巷33號
# 4     500101005    辛亥復興路口西北側     大安區  2024-11-08 07:59:16     復興南路二段368號
# ...         ...          ...     ...                  ...            ...
# 1488  500119092     臺大管理學院一館  臺大公館校區  2024-11-08 07:50:16      臺大管理學院一館前
# 1489  500119093      臺大禮賢樓西側  臺大公館校區  2024-11-08 07:52:14      臺大禮賢樓西側空地
# 1490  500119094    臺大大一女餐廳廣場  臺大公館校區  2024-11-08 07:56:15    臺大大一女餐廳廣場後方
# 1491  500119095        臺大學新館  臺大公館校區  2024-11-08 07:46:14         臺大學新館旁
# 1492  500119096     臺大水源舍區C棟  臺大公館校區  2024-11-08 08:00:17     臺大水源舍區C棟西側
#
#          sareaen                                              snaen  \
# ...

# %%
valid[["sna", 'latitude', 'longitude','available_rent_bikes','available_return_bikes','total']]
# Out:
#               sna  latitude  longitude  available_rent_bikes  \
# 0         捷運科技大樓站  25.02605  121.54360                    10
# 1     復興南路二段273號前  25.02565  121.54357                     2
# 2       國北教大實小東側門  25.02429  121.54124                     7
# 3          和平公園東側  25.02351  121.54282                     3
# 4       辛亥復興路口西北側  25.02153  121.54299                     4
# ...           ...       ...        ...                   ...
# 1483     臺大管理學院一館  25.01436  121.53828                     0
# 1484      臺大禮賢樓西側  25.01467  121.53765                    25
# 1485    臺大大一女餐廳廣場  25.01479  121.53494                    14
# 1486        臺大學新館  25.01944  121.54339                    17
# 1487     臺大水源舍區C棟  25.01547  121.52892                    54
#
#       available_return_bikes  total
# 0                         17     28
# 1                         17     21
# 2                          9     16
# 3                          8     11
# 4                         12     16
# ...
